# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal
from matplotlib import cm
import os
import math
from scipy import optimize
import openpyxl

# %%
fs = 20
fw = 1000
fig = plt.figure(figsize=(15,15),dpi=80)
ax1 = fig.add_subplot(3,1,1)
ax1.plot(capacity_z,V_D_Std_Wei,label="Weighting Method")
ax1.plot(capacity_z,ans_beam_pattern2_abs,label="Function G Method")
ax1.set_title("Weighting Method & Function G Method",fontsize=fs,fontweight=fw)
ax1.tick_params(labelbottom=False,labelsize="20")
ax1.set_xlim(xmin=0)
ax1.set_ylim(ymin=0)
ax1.legend(loc="upper right",fontsize=fs-8)
ax1.grid()

ax2 = fig.add_subplot(3,1,2)
ax2.scatter(capacity_z,V_D_Std_Wei,label="Weighting Method")
ax2.scatter(capacity_z,ans_beam_pattern2_abs,label="Function G Method")
ax2.tick_params(labelbottom=False,labelsize="20")
ax2.set_xlim(xmin=0)
ax2.set_ylim(ymin=0)
ax2.set_ylabel("σ of Beam Broadening (m/s)",fontsize=fs,fontweight=fw)
ax2.grid()

ax3 = fig.add_subplot(3,1,3)
ax3.scatter(capacity_z,V_D_Std_Wei,label="Weighting Method")
ax3.scatter(capacity_z,ans_beam_pattern2_abs,label="Function G Method")
for i in range(capacity_z.size):
    ax3.vlines(capacity_z[i],np.min(ans_beam_pattern2_abs),np.max(V_D_Std_Wei),color="r",linestyle="--")
ax3.set_xlabel("Height(m)",fontsize=fs,fontweight=fw)
ax3.set_xlim(xmin=0)
ax3.set_ylim(ymin=0)
ax3.tick_params(labelsize="20")
ax3.grid()
